# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url="https://www.ebay.com/sch/i.html?_nkw=laptops&_sacat=0&_from=R40&_trksid=p4624852.m570.l1311"

# %%
response=requests.get(url)

# %%
soup=BeautifulSoup(response.text,"html.parser")

# %%
soup
# Out:
# <html><head>
# <title>Access Denied</title>
# </head><body>
# <h1>Access Denied</h1>
#
# You don't have permission to access "http://www.ebay.com/sch/i.html?" on this server.<p>
# Reference #18.d76ad717.1778872679.452e19a3
# <p>https://errors.edgesuite.net/18.d76ad717.1778872679.452e19a3</p>
# </p></body>
# </html>
